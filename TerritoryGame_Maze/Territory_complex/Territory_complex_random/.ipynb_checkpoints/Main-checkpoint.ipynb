# %%
import sys
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
print(os.getcwd())
# Out:
# C:\Users\sleepybear\TerritoryGame_Maze\Territory_complex\Territory_complex_random

# %%
sys.path.append('C:/Users/sleepybear/TerritoryGame_Maze')
from TerritoryGame_MaPolicy import PPO  #指定路径导入一个名为TerritoryGame_MaPolicy的模块Specify the path to import a module named TerritoryGame_MaPolicy

# %%
sys.path.append('C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/Territory_complex_random')
from TerritoryGame_New_Random_Env import TerritoryBattleEnvCoopRandom

# %%
import logging
import pygame
import moviepy.editor as mpy

# %%
import tensorflow as tf
import numpy as np

# %%
sys.path.append('C:/Users/sleepybear/TerritoryGame_Maze')
from visualization import Visualization  # Import visualization class

# %%
import scipy.spatial

# %%
import time

# %%
def compute_policy_similarity(policy1, policy2):
    return scipy.spatial.distance.cosine(policy1.flatten(), policy2.flatten())
def detect_policy_switch(previous_policy, current_policy, threshold=0.1):
    return np.linalg.norm(previous_policy - current_policy) > threshold

# %% [markdown]
# #This code will save the pygame video after running, which will cause 5 minutes of unresponsiveness.
# #If you don't want the video, you need to remove the code and storage list for saving the video.

# %%
def main():
    env = TerritoryBattleEnvCoopRandom(grid_size=12, max_steps=150)
    num_agents = env.num_agents
    state_size = env.observation_space.shape[0] * env.observation_space.shape[1]
    action_size = env.action_space.n
    
    ppo = PPO(state_size=state_size, action_size=action_size, num_agents=num_agents)
    ppo.load("C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model")

    num_episodes = 100
    batch_size = 32

    vis = Visualization(env)

    # 创建一个新的日志目录，每次运行时带有时间戳Create a new log directory with a timestamp each time it is run
    log_dir = os.path.join("logs", "analysis", f"run_{int(time.time())}")
    summary_writer = tf.summary.create_file_writer(log_dir)

    # 存储帧的列表，用于保存视频A list of storage frames, used to save video
    frames = []

    with open('output.txt', 'w') as file:
        file.write("Episode,Total_Red_Reward,Total_Blue_Reward,Red_Territories,Blue_Territories\n")

        win_counts = np.zeros(num_agents)
        previous_policies = [None] * num_agents
        policy_switches = np.zeros(num_agents)

        for episode in range(num_episodes):
            state = env.reset().flatten()
            done = False
            total_red_reward = 0
            total_blue_reward = 0
            step_count = 0

            all_states, all_actions, all_rewards_per_step, all_old_probs, all_values = [], [], [], [], []
            red_rewards, blue_rewards = [], []
            policy_similarities = []

            while not done and step_count < env.max_steps:
                step_count += 1

                actions = []
                action_probs = []
                policies = []

                for agent_index in range(num_agents):
                    action, policy = ppo.get_action(state, agent_index)
                    actions.append(action)
                    action_probs.append(policy)
                    policies.append(policy)

                next_state, rewards, done, info = env.step(actions)

                all_states.append(state)
                all_actions.append(actions)
                all_rewards_per_step.append(np.sum(rewards))
                all_old_probs.append(action_probs)

                red_rewards.append(np.sum([reward if agent['team'] == 'red' else 0 for reward, agent in zip(rewards, env.agents)]))
                blue_rewards.append(np.sum([reward if agent['team'] == 'blue' else 0 for reward, agent in zip(rewards, env.agents)]))

                # 记录对抗结果Record the confrontation results
                red_team_wins = info['red_count'] > info['blue_count']
                blue_team_wins = info['blue_count'] > info['red_count']

                for i, agent in enumerate(env.agents):
                    if agent['team'] == 'red' and red_team_wins:
                        win_counts[i] += 1
                    elif agent['team'] == 'blue' and blue_team_wins:
                        win_counts[i] += 1

                # 计算策略相似性Calculating strategy similarity
                for i in range(num_agents):
                    for j in range(i + 1, num_agents):
                        similarity = compute_policy_similarity(policies[i], policies[j])
                        policy_similarities.append(similarity)

                # 检测策略切换Detection strategy switching
                for agent_index in range(num_agents):
                    if previous_policies[agent_index] is not None:
                        if detect_policy_switch(previous_policies[agent_index], policies[agent_index]):
                            policy_switches[agent_index] += 1
                    previous_policies[agent_index] = policies[agent_index]

                for agent_index in range(num_agents):
                    value = ppo.value_models[agent_index](tf.convert_to_tensor(state[None, :])).numpy()[0]
                    all_values.append(value)

                state = next_state.flatten()
                total_red_reward += np.sum([reward if agent['team'] == 'red' else 0 for reward, agent in zip(rewards, env.agents)])
                total_blue_reward += np.sum([reward if agent['team'] == 'blue' else 0 for reward, agent in zip(rewards, env.agents)])

                vis.update(episode)
                env.handle_events()

                # 捕获当前帧并添加到帧列表Capture the current frame and add it to the frame list
                frame = pygame.surfarray.array3d(pygame.display.get_surface())
                frame = frame.transpose([1, 0, 2])
                frames.append(frame)

            if (episode + 1) % batch_size == 0:
                with summary_writer.as_default():
                    for agent_index in range(num_agents):
                        tf.summary.scalar(f"Agent_{agent_index}_Reward", total_red_reward if env.agents[agent_index]['team'] == 'red' else total_blue_reward, step=episode)
                        tf.summary.scalar(f"Agent_{agent_index}_Win_Rate", win_counts[agent_index] / (episode + 1), step=episode)
                        tf.summary.scalar(f"Agent_{agent_index}_Policy_Switches", policy_switches[agent_index], step=episode)
                    tf.summary.scalar(f"Average_Policy_Similarity", np.mean(policy_similarities), step=episode)

            output = (
                f"{episode + 1},{total_red_reward},{total_blue_reward},"
                f"{info['red_count']},{info['blue_count']}\n"
            )
            print(output)
            logging.info(f"Episode {episode + 1} completed: {output.strip()}")
            file.write(output)

        # 保存帧列表为视频 Save frame list as video
        clip = mpy.ImageSequenceClip(frames, fps=30)
        clip.write_videofile("pygame_recording.mp4", codec="libx264")

        vis.show()
        summary_writer.close()
        logging.info("Training completed.")

if __name__ == "__main__":
    try:
        main()
    except SystemExit:
        pass
# Out:
# Loading model from: C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model_policy_0.h5
# Loading model from: C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model_policy_1.h5
# Loading model from: C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model_policy_2.h5
# Loading model from: C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model_policy_3.h5
# Loading model from: C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model_value_0.h5
# Loading model from: C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model_value_1.h5
# Loading model from: C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model_value_2.h5
# Loading model from: C:/Users/sleepybear/TerritoryGame_Maze/Territory_complex/model/ppo_Territory_complex_model_value_3.h5
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (5, 9)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 1,42.89999999999993,50.099999999999945,53,47
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (3, 7)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (4, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 2,42.29999999999995,40.79999999999998,66,38
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (6, 2)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 3,39.19999999999996,23.799999999999976,47,40
#
# 4,39.39999999999996,33.099999999999994,44,43
#
# 5,48.199999999999875,29.399999999999988,32,48
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (1, 10)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (4, 5)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 6,47.09999999999996,38.89999999999991,44,41
#
# 7,73.30000000000001,39.399999999999956,58,51
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (10, 4)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 8,44.99999999999991,66.69999999999996,57,62
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (4, 5)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 9,47.99999999999993,39.29999999999988,59,46
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (1, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 10,66.69999999999986,23.29999999999998,42,53
#
# 11,27.4,37.89999999999997,38,52
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (10, 9)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 12,47.69999999999995,23.899999999999988,70,42
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (6, 1)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (3, 0)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (0, 3)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (2, 4)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 13,10.300000000000018,53.299999999999855,37,48
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (3, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 14,39.59999999999995,37.699999999999946,52,43
#
# 15,30.59999999999998,47.89999999999989,37,50
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (11, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (6, 6)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 16,57.39999999999994,54.399999999999885,56,54
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (8, 2)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 17,24.899999999999977,66.3999999999999,44,67
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (4, 0)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (2, 7)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (0, 7)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (2, 4)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 18,22.39999999999989,101.99999999999991,32,64
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (3, 9)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (6, 5)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 19,82.70000000000016,18.700000000000014,62,37
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (8, 9)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 20,84.19999999999996,28.29999999999993,70,51
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (2, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 21,56.79999999999988,21.9,45,49
#
# 22,60.499999999999865,45.09999999999989,54,48
#
# 23,29.900000000000002,42.699999999999925,60,47
#
# 24,39.599999999999945,74.40000000000003,48,54
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (7, 1)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (4, 4)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (5, 4)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (7, 7)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 25,58.29999999999992,57.39999999999997,44,68
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (8, 2)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 26,67.69999999999995,12.600000000000028,62,42
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (0, 4)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (3, 8)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (3, 6)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 27,26.499999999999968,72.59999999999995,36,64
#
# 28,71.79999999999984,27.7,41,33
#
# 29,38.09999999999996,44.49999999999996,67,45
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (2, 5)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (1, 7)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 30,71.40000000000002,17.700000000000028,40,54
#
# 31,53.19999999999982,29.899999999999974,43,40
#
# 32,32.19999999999999,34.69999999999997,51,48
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (0, 7)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 33,59.799999999999955,47.999999999999886,66,46
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (11, 7)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 34,20.600000000000016,45.89999999999991,63,38
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (6, 10)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 35,40.39999999999993,23.299999999999976,65,36
#
# 36,52.29999999999992,32.19999999999996,44,61
#
# 37,46.199999999999896,55.99999999999987,37,53
#
# 38,32.499999999999986,54.79999999999997,33,69
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (1, 0)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (1, 2)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 39,36.199999999999825,80.39999999999995,37,71
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (3, 5)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 40,48.599999999999895,24.399999999999977,58,43
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (8, 7)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 41,30.299999999999986,43.19999999999989,58,33
#
# 42,25.999999999999996,40.09999999999992,41,44
#
# 43,33.199999999999974,51.49999999999983,52,51
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (9, 4)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 44,48.19999999999987,46.49999999999995,50,57
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (0, 7)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 45,47.699999999999925,45.89999999999996,40,72
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (8, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 46,48.19999999999996,28.59999999999996,54,35
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (7, 2)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (8, 4)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 47,35.69999999999999,60.39999999999993,60,54
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (6, 9)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 48,65.99999999999993,30.3,50,40
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (0, 7)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 49,39.99999999999991,50.599999999999945,38,59
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (5, 0)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 50,42.79999999999997,45.69999999999995,35,62
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (0, 5)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 51,52.399999999999906,28.400000000000002,58,56
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (8, 11)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (11, 6)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 52,33.89999999999994,70.9999999999999,57,36
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (5, 11)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (4, 10)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 53,56.29999999999987,55.599999999999895,52,66
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (6, 5)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (11, 8)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (10, 8)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (8, 7)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 54,51.09999999999993,26.199999999999942,50,33
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (1, 6)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 55,25.099999999999984,47.4999999999999,36,61
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (0, 0)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 56,19.00000000000002,57.699999999999925,28,58
#
# 57,37.199999999999946,53.59999999999996,55,59
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (3, 8)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 58,24.39999999999999,66.19999999999997,46,68
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (10, 3)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 59,68.79999999999994,33.99999999999998,61,38
#
# 60,52.1999999999999,59.59999999999988,69,52
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (4, 8)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (1, 2)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (1, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (0, 1)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 61,8.100000000000025,62.89999999999996,33,70
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (10, 0)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 62,25.09999999999999,47.79999999999993,64,54
#
# 63,53.0999999999999,53.59999999999989,47,56
#
# 64,34.199999999999996,52.69999999999986,51,57
#
# 65,38.499999999999915,32.59999999999995,63,42
#
# 66,53.79999999999983,42.899999999999906,37,63
#
# 67,45.199999999999925,44.49999999999994,52,61
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (2, 0)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 68,36.0999999999999,44.39999999999997,32,56
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (2, 8)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (3, 11)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 69,94.60000000000002,18.69999999999996,54,68
#
# 70,58.29999999999988,34.99999999999994,61,52
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (6, 2)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (5, 3)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 71,46.999999999999986,55.09999999999997,51,51
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (6, 1)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (9, 1)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 72,80.60000000000007,8.100000000000012,66,19
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (1, 8)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (1, 4)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 73,22.199999999999996,58.39999999999995,42,72
#
# 74,62.99999999999992,37.099999999999966,56,52
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (7, 7)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 75,50.39999999999993,43.89999999999989,60,53
#
# 76,63.19999999999997,27.999999999999996,48,48
#
# 77,34.29999999999995,33.59999999999996,40,62
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (9, 2)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (5, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 78,87.5000000000001,13.700000000000015,69,30
#
# 79,30.699999999999957,61.39999999999991,47,73
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (9, 6)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 80,59.89999999999997,44.199999999999896,63,53
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (2, 5)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 81,42.39999999999995,23.90000000000001,66,51
#
# 82,30.00000000000001,60.19999999999993,34,61
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (6, 4)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 83,60.799999999999926,11.200000000000015,61,30
#
# 84,43.89999999999994,39.29999999999995,75,36
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (7, 9)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 85,67.89999999999993,28.599999999999962,65,47
#
# 86,57.49999999999989,54.99999999999988,64,51
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (6, 0)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 87,42.69999999999994,23.70000000000002,63,44
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (5, 4)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (6, 8)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 88,30.09999999999994,50.59999999999989,53,37
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (5, 4)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (4, 5)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 89,19.4,62.49999999999987,36,72
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (2, 2)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (9, 4)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 90,74.69999999999996,14.700000000000022,43,61
#
# Attacker 0 (Team red) attacks Enemy 2 (Team blue) at position (6, 11)
# Team red (Agent 0) receives +10 reward. Total reward: 10.0
# 91,72.29999999999997,26.79999999999998,70,47
#
# 92,55.29999999999991,59.69999999999989,58,61
#
# 93,41.19999999999993,56.99999999999991,47,48
#
# 94,36.599999999999945,55.09999999999986,40,61
#
# 95,60.19999999999982,63.399999999999864,48,60
#
# 96,29.09999999999999,56.59999999999989,55,49
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (3, 9)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 97,24.70000000000001,44.99999999999987,49,51
#
# Attacker 0 (Team red) attacks Enemy 3 (Team blue) at position (2, 4)
# Team red (Agent 0) receives +10 reward. Total reward: 9.9
# 98,43.59999999999991,40.99999999999991,43,54
#
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (3, 2)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (2, 0)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# Attacker 2 (Team blue) attacks Enemy 1 (Team red) at position (1, 0)
# Team blue (Agent 2) receives +10 reward. Total reward: 9.9
# 99,2.7000000000000126,68.8,43,67
#
# Attacker 2 (Team blue) attacks Enemy 0 (Team red) at position (8, 6)
# Team blue (Agent 2) receives +10 reward. Total reward: 10.0
# 100,27.6,72.29999999999997,45,67
#
# Moviepy - Building video pygame_recording.mp4.
# Moviepy - Writing video pygame_recording.mp4
# Moviepy - Done !
# Moviepy - video ready pygame_recording.mp4

# %% [markdown]
# #If you want to use tensorboard, you must first clear the files in the analysis folder to ensure that there is only one curve.
# #If you do not clear it, the results of multiple trainings in different timelines will be displayed.
# #You also need to end the previous tensorboard process in the task manager, otherwise the server will still display the last training results.

# %%
# 启动 TensorBoard
# !tensorboard --logdir logs/analysis --port=6010
#http://localhost:6010
# Out:
# 2024-09-03 11:52:38.360368: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-03 11:52:42.708920: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.17.0 at http://localhost:6010/ (Press CTRL+C to quit)
